# %%
# !pip install -q python-dotenv

# %%
import pandas as pd
import openai
import os

# %%
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
openai.api_key="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"

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
text = f"""
You should express what you want a model to do by \ 
providing instructions that are as clear and \ 
specific as you can possibly make them. \ 
This will guide the model towards the desired output, \ 
and reduce the chances of receiving irrelevant \ 
or incorrect responses. Don't confuse writing a \ 
clear prompt with writing a short prompt. \ 
In many cases, longer prompts provide more clarity \ 
and context for the model, which can lead to \ 
more detailed and relevant outputs.
"""
prompt = f"""
Summarize the text delimited by triple backticks \ 
into a single sentence.
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# To guide a model towards the desired output and reduce irrelevant or incorrect responses, it is important to provide clear and specific instructions, which can be achieved through longer prompts that offer more clarity and context.

# %%
prompt = f"""
use this datas delimated by triple backticks\
to answer my questions.
```{df_respondants}```
"""
response=get_completion(prompt)
print(response)
# Out:
# 1. How many respondents are there in the dataset?
# There are 10,000 respondents in the dataset.
#
# 2. What is the age range of the respondents?
# The age range of the respondents is from 15-18 to 31-45.
#
# 3. What is the gender distribution among the respondents?
# The gender distribution among the respondents is as follows:
# - Female: 2,500
# - Male: 7,500
#
# 4. How many different cities are represented in the dataset?
# There are multiple cities represented in the dataset, but the number of different cities is not specified in the given data.
#
# 5. Can you provide the Respondent_ID, Name, Age, Gender, and City_ID of the respondent with the ID 120034?
# The Respondent_ID, Name, Age, Gender, and City_ID of the respondent with the ID 120034 are as follows:
# - Respondent_ID: 120034
# - Name: Pranay Chand
# - Age: 31-45
# - Gender: Female
# - City_ID: CT113

# %%
text=f"""
Who prefers energy drink more? (male/female/non-binary?)\
Which age group prefers energy drinks more?\
Which type of marketing reaches the most Youth (15-30)?\
"""
prompt = f"""
answer the questions delimated by triple backticks\
by using the data that i have provided before.
```{text}```
"""
response=get_completion(prompt)
print(response)
# Out:
# Based on the data provided before, we cannot determine who prefers energy drinks more between males, females, and non-binary individuals as the data does not include information on gender preferences for energy drinks.
#
# Regarding the age group that prefers energy drinks more, the data does not provide specific age ranges or preferences related to energy drinks. Therefore, we cannot determine which age group prefers energy drinks more based on the given data.
#
# Similarly, the data does not include information on the type of marketing that reaches the most youth (15-30). Therefore, we cannot determine which type of marketing is most effective in reaching this age group based on the provided data.

# %%
df_fact=pd.read_csv(r'G:\powerbi\C6 Input Files\Dataset\fact_survey_responses.csv')
df_cities=pd.read_csv(r'G:\powerbi\C6 Input Files\Dataset\dim_cities.csv')
df_respondants=pd.read_csv(r'G:\powerbi\C6 Input Files\Dataset\dim_repondents.csv')

# %%
df_fact.head()
# Out:
#    Response_ID  Respondent_ID  Consume_frequency  \
# 0       103001         120031   2-3 times a week
# 1       103002         120032  2-3 times a month
# 2       103003         120033             Rarely
# 3       103004         120034   2-3 times a week
# 4       103005         120035              Daily
#
#                       Consume_time              Consume_reason Heard_before  \
# 0  To stay awake during work/study  Increased energy and focus          Yes
# 1               Throughout the day        To boost performance           No
# 2                  Before exercise  Increased energy and focus           No
# 3  To stay awake during work/study        To boost performance           No
# 4  To stay awake during work/study  Increased energy and focus          Yes
#
#   Brand_perception General_perception Tried_before  Taste_experience  ...  \
# 0          Neutral           Not sure           No                 5  ...
# ...

# %%
df_cities.head()
# Out:
#   City_ID       City    Tier
# 0   CT111      Delhi  Tier 1
# 1   CT112     Mumbai  Tier 1
# 2   CT113  Bangalore  Tier 1
# 3   CT114    Chennai  Tier 1
# 4   CT115    Kolkata  Tier 2

# %%
df_respondants.head()
# Out:
#    Respondent_ID            Name    Age  Gender City_ID
# 0         120031  Aniruddh Issac  15-18  Female   CT117
# 1         120032     Trisha Rout  19-30    Male   CT118
# 2         120033    Yuvraj  Virk  15-18    Male   CT116
# 3         120034    Pranay Chand  31-45  Female   CT113
# 4         120035  Mohanlal Joshi  19-30  Female   CT120
